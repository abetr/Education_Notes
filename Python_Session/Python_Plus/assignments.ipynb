# %%
def sum_double(x, y):
    if x != y :
        return(x+y)
    else :
        return((x+y)*2)

sum_double(8,8)
# Out:
# 32

# %%
# print(set("12345678"))

for x in set("pqr"):
    print(x)
    

    # print(ord(x))
# Out:
# p
# r
# q

# %%
ord("q")
# Out:
# 113

# %%
ord("p")
# Out:
# 112

# %%
ord("r")
# Out:
# 114

# %%
x=set(["a","b"])
x
# Out:
# {'a', 'b'}

# %%
fruits = {'Apples': 5, 'Oranges': 3, 'Bananas': 4}

fruit_names = [x for x in fruits.keys()]
fruit_names
# Out:
# ['Apples', 'Oranges', 'Bananas']

# %%
i = 5
while True:
    if i%0xe == 0:
        break
    print(i)
    i += 1
# Out:
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13

# %%
x = "abcd"
for i in range(len(x)):
    i[x].upper()
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/ahmetburakeren/Notes/Education_Notes/Python_Session/Python Plus/assignments.ipynb Cell 9' in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Notes/Education_Notes/Python_Session/Python%20Plus/assignments.ipynb#ch0000008vscode-remote?line=0'>1</a> x = "abcd"
#       <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Notes/Education_Notes/Python_Session/Python%20Plus/assignments.ipynb#ch0000008vscode-remote?line=1'>2</a> for i in range(len(x)):
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Notes/Education_Notes/Python_Session/Python%20Plus/assignments.ipynb#ch0000008vscode-remote?line=2'>3</a>     i[x].upper()
# ...

# %%
a = [1,2,3]
list(reversed(a))
# Out:
# [3, 2, 1]

# %%
print(0xA+0xB+0xC)
# Out:
# 33

# %%
print("new" "line" "end", 3)
# Out:
# newlineend 3

# %%
example = "snow world"
example[3] = 's'
print(example)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus/assignments.ipynb Cell 13' in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus/assignments.ipynb#ch0000012vscode-remote?line=0'>1</a> example = "snow world"
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus/assignments.ipynb#ch0000012vscode-remote?line=1'>2</a> example[3] = 's'
#       <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus/assignments.ipynb#ch0000012vscode-remote?line=2'>3</a> print(example)
#
# TypeError: 'str' object does not support item assignment

# %%
print(max("joseph"))
# Out:
# s

# %%
example = "hello"
print(example.count("l"))
# Out:
# 2

# %%
example = "helen"
print(example.find("e"))
# Out:
# 1

# %%
print("hello\example\test.txt")
# Out:
# hello\example	est.txt

# %%
print("hello\"example\"test.txt")
# Out:
# hello"example"test.txt

# %%
print("hello\n\example\n\test.txt")
# Out:
# hello
# \example
# 	est.txt

# %%
print("hello\\example\\test.txt")
# Out:
# hello\example\test.txt

# %%
s = "\t\tWorld\n"
print(s.strip())
# Out:
# World

# %%
print("hello" +"1+2+"3")
# Out:
#   Input In [14]
#     print("hello" +"1+2+"3")
#                          ^
# SyntaxError: invalid syntax

# %%
d = {}
d[None] = "This is tricky"
d
# Out:
# {None: 'This is tricky'}

# %%
if 1 + 1 == 2:
   if 2 * 2 == 8:
      print("if")
   else:
      print("else")
# Out:
# else

# %%
if not True:
   print("1")
elif not (1 + 1 == 3):
   print("2")
else:
   print("3")
# Out:
# 2

# %%
x = 0
while x<=10:
  print(x if x % 2 == 0 else None)
  x +=1
# Out:
# 0
# None
# 2
# None
# 4
# None
# 6
# None
# 8
# None
# 10

# %%
total = 0
i = 5
while i > 0:
    user_age = int(input())
    i -= 1
    if user_age > 3:
        total += 100        
    else :        
        continue    
    
print(total)
# Out:
# 400

# %%
while False:
  print("Looping...")

# %%
i = 0
x = 0
while i < 4:
    x+=i
    i+=1

print(x)
# Out:
# 6

# %%
x = 0
while x<=10:
    if x % 2 == 0:
        print(x)
    else:
        pass
    x+=1
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
weight = int(input())
height = float(input())
bmi = weight / (height)**2

if bmi < 18.5:
    print("Underweight")
elif bmi >= 18.5 and bmi < 25:
    print("Normal")
elif bmi >= 25 and bmi < 30:
    print("Overweight")
elif bmi >= 30 :
    print("Obesity")
# Out:
# Normal

# %%
a = int(input())
b = int(input())
print(list(range(a,b)))
# Out:
# [2005, 2006, 2007, 2008, 2009, 2010]

# %%
a = input()
print(a[-1])
# Out:
# r

# %%
names ="names"
names[1:-1]
# Out:
# 'ame'

# %%
N = int(input())
total = 0
for i in range(1,N+1):
    total += i

print(total)
# Out:
# 5050

# %%
len(range(0, 100, 5))
# Out:
# 20

# %%
x = [2, 4, 5, 7, 4]
y = x.index(4)
print(y)
# Out:
# 1

# %%
list = [8, 4, 2, 6]
list.remove(2)
print(len(list)+list.count(6))
# Out:
# 4

# %%
queue = ['John', 'Amy', 'Bob', 'Adam']
n = input()
queue.append(n)
print(queue)
# Out:
# ['John', 'Amy', 'Bob', 'Adam', 'abuş']

# %%
msg = input()
a = msg.replace("#"," ")
print(a)
# Out:
# a b c d

# %%
def welcome():
    user = input()
    print(f"Welcome, {user}")

welcome()
# Out:
# Welcome, Tommy

# %%
pwd
# Out:
# '/home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus'

# %%
with open("alcohol.csv", "r", encoding ="UTF8") as file:
    print(file.readline())
# Out:
# Series_reference,Period,Data_value,STATUS,UNITS,MAGNITUDE,Subject,Group,Series_title_1,Series_title_2,Series_title_3,Series_title_4,Series_title_5

# %%
with open("alcohol.csv", "r", encoding ="UTF8") as file:
    total = 0
    for line in file:
        if line.split(",")[5] != "MAGNITUDE":
            total += int(line.split(",")[5])

    print(total)
# Out:
# 43470

# %%
with open("alcohol.csv", "r", encoding ="UTF8") as file:
    total = 0
    for line in file:
        print(line.split(",")[1])
# Out:
# Period
# 1935.12
# 1936.12
# 1937.12
# 1938.12
# 1939.12
# 1940.12
# 1941.12
# 1942.12
# 1943.12
# 1944.12
# 1945.12
# 1946.12
# 1947.12
# 1948.12
# 1949.12
# 1950.12
# 1951.12
# 1952.12
# 1953.12
# 1954.12
# 1955.12
# 1956.12
# 1957.12
# 1958.12
# 1959.12
# 1960.12
# 1961.12
# 1962.12
# 1963.12
# 1964.12
# 1965.12
# 1966.12
# 1967.12
# 1968.12
# 1969.12
# 1970.12
# 1971.12
# 1972.12
# 1973.12
# 1974.12
# 1975.12
# 1976.12
# 1977.12
# 1978.12
# 1979.12
# 1980.12
# 1981.12
# 1935.06
# 1936.06
# 1937.06
# 1938.06
# 1939.06
# 1940.06
# 1941.06
# 1942.06
# 1943.06
# 1944.06
# 1945.06
# 1946.06
# 1947.06
# 1948.06
# 1949.06
# 1950.06
# 1951.06
# 1952.06
# 1953.06
# 1954.06
# 1955.06
# 1956.06
# 1957.06
# 1958.06
# 1959.06
# 1960.06
# 1961.06
# 1962.06
# 1963.06
# 1964.06
# 1965.06
# 1966.06
# 1967.06
# 1968.06
# 1969.06
# 1970.06
# 1971.06
# 1972.06
# 1973.06
# 1974.06
# 1975.06
# 1976.06
# 1977.06
# 1978.06
# 1979.06
# 1980.06
# 1981.06
# 1935.12
# 1936.12
# 1937.12
# 1938.12
# 1939.12
# ...

# %%
with open("titanic.csv", "r", encoding ="UTF8") as file:
    print(file.readline())
# Out:
# PassengerId,Survived,Pclass,Name,Sex,Age,SibSp,Parch,Ticket,Fare,Cabin,Embarked

# %%
with open("titanic.csv", "r", encoding ="UTF8") as file:
    total = 0
    for line in file:
        if line.split(",")[1] != "Survived":
            total += int(line.split(",")[1])
    print(total)
# Out:
# 342

# %%
with open("titanic.csv", "r", encoding ="UTF8") as file:
    total = 0
    for line in file:
        if line.split(",")[1] != "Survived":
            if line.split(",")[4] == "female" :
                total += int(line.split(",")[1])
    print(total)
# Out:
# 0

# %%
count = 0
my_string = "Clarusway"
my_char = "a"
for i in my_string :
    if i == my_char:
        count += 1
print(count)
# Out:
# 2

# %%
x = 8
y=10
assert x>y, "X too small"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus/assignments.ipynb Cell 51' in <cell line: 3>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus/assignments.ipynb#ch0000050vscode-remote?line=0'>1</a> x = 8
#       <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus/assignments.ipynb#ch0000050vscode-remote?line=1'>2</a> y=10
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu20.04lts/home/ahmetburakeren/Education_Notes/Python_Session/Python_Plus/assignments.ipynb#ch0000050vscode-remote?line=2'>3</a> assert x>y, "X too small"
#
# AssertionError: X too small
